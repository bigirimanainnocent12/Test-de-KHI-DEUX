# %% [markdown]
# <a href="https://colab.research.google.com/github/bigirimanainnocent12/Test-de-KHI-DEUX/blob/main/Test_de_khi_deux.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Test de khi-deux d'indépendances***
#
# L'objectif de cette analyse statistique est de déterminer si la couleur des cheveux est indépendante du sexe dans un échantillon composé de garçons et de filles d'un district écossais. Pour ce faire, nous allons utiliser un test d'indépendance approprié afin de vérifier s'il existe une relation significative entre la couleur des cheveux et le sexe des individus observés.
#
# En analysant les données présentées dans le tableau ci-dessous, nous pourrons évaluer si la répartition des couleurs de cheveux diffère de manière significative entre les garçons et les filles de cet échantillon.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

obs=np.array([[592,544],[119,97],[849,677],[504,451],[36,14]])
# Transpose the obs array to have shape (5, 2) to match the index and columns
df=pd.DataFrame(obs, index=list(["BLOND", "ROUX", "CHATAIN","BRUN","NOIR"]), columns=list( ["HOMME", "FEMME"]))

df.loc[["BLOND", "ROUX", "CHATAIN","BRUN","NOIR"], ["HOMME", "FEMME"]]
df
# Out:
#          HOMME  FEMME
# BLOND      592    544
# ROUX       119     97
# CHATAIN    849    677
# BRUN       504    451
# NOIR        36     14
